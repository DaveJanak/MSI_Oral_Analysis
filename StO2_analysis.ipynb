# %%
import numpy as np
import matplotlib.pyplot as plt
from spectral import *
from scipy import linalg
import scipy.stats as stats
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from scipy.spatial.distance import euclidean
from scipy.stats import f_oneway
import pandas as pd
import cv2
import glob
import os

# %%
class DataProcessor:
    def __init__(self, msi_data_dir, msi_masks_dir, msi_rgbs_dir):
                  
        self.msi_data_dir = msi_data_dir
        self.msi_masks_dir = msi_masks_dir
        self.msi_rgbs_dir = msi_rgbs_dir

        self.msi_imgs = []
        self.msi_masks = []
        self.msi_rgbs = []
        self.msi_data_name = []
        self.msi_masks_name = []
        self.msi_rgbs_name = []

    def load_multispectral_data(self, data_dir, imgs_list, data_name):
        # msi_files = data_dir 
        msi_files = glob.glob(os.path.join(data_dir))
        for msi_file in msi_files:
            img_data = open_image(msi_file)
            imgs_list.append(np.asarray(img_data.load()))
            img_filename = os.path.basename(msi_file)
            data_name.append(img_filename)

    def load_masks(self, masks_dir, masks_list, masks_name):
        # mask_files = masks_dir
        mask_files = glob.glob(os.path.join(masks_dir))
        for mask_file in mask_files:
            mask_data = cv2.imread(mask_file, cv2.IMREAD_GRAYSCALE)
            _, mask_data = cv2.threshold(mask_data, 0, 1, cv2.THRESH_BINARY)
            masks_list.append(mask_data)
            mask_filename = os.path.basename(mask_file)
            masks_name.append(mask_filename)

    def load_rgbs(self, rgbs_dir, rgbs_list, rgbs_name):
        # rgb_files = rgbs_dir
        rgb_files = glob.glob(os.path.join(rgbs_dir))
        for rgb_file in rgb_files:
            rgb_im = cv2.imread(rgb_file)
            rgb_im = cv2.cvtColor(rgb_im, cv2.COLOR_BGR2RGB)
            rgbs_list.append(rgb_im)
            rgb_filename = os.path.basename(rgb_file)
            rgbs_name.append(rgb_filename)

    def process_data(self):
        self.load_multispectral_data(self.msi_data_dir, self.msi_imgs, self.msi_data_name)
        self.load_masks(self.msi_masks_dir, self.msi_masks, self.msi_masks_name)
        self.load_rgbs(self.msi_rgbs_dir, self.msi_rgbs, self.msi_rgbs_name)

# %%
# Create an instance of the DataProcessor class and process the data
base_dir = "C:/Users/htic/Documents/MSI_dataset_Copy/"

data_processor = DataProcessor(

    #Read all the data
    msi_data_dir =  os.path.join(base_dir, "data/*/*.hdr"), 
    msi_masks_dir = os.path.join(base_dir, "masks/*.png"),
    msi_rgbs_dir =  os.path.join(base_dir, "rgb/*.png")

)
data_processor.process_data()

# %%
# Custom sorting function to extract the numerical part of the filename
def sort_key(filename):
    return int(''.join(filter(str.isdigit, filename)))

# Sort the filenames using the custom sorting function
sorted_data_names = sorted(data_processor.msi_data_name, key=sort_key)
sorted_mask_names = sorted(data_processor.msi_masks_name, key=sort_key)
sorted_rgb_names = sorted(data_processor.msi_rgbs_name, key=sort_key)

# Print the sorted filenames
for i, (data_name, mask_name, rgb_name) in enumerate(zip(sorted_data_names, sorted_mask_names, sorted_rgb_names)):
    print(f"{i}. Data = {data_name}, Mask = {mask_name}, RGB = {rgb_name}")
# Out:
# 0. Data = 1.hdr, Mask = 1.png, RGB = 1.png
# 1. Data = 2.hdr, Mask = 2.png, RGB = 2.png
# 2. Data = 3.hdr, Mask = 3.png, RGB = 3.png
# 3. Data = 4.hdr, Mask = 4.png, RGB = 4.png
# 4. Data = 6.hdr, Mask = 6.png, RGB = 5.png
# 5. Data = 7.hdr, Mask = 7.png, RGB = 6.png
# 6. Data = 8.hdr, Mask = 8.png, RGB = 7.png
# 7. Data = 9.hdr, Mask = 9.png, RGB = 8.png
# 8. Data = 10.hdr, Mask = 10.png, RGB = 9.png
# 9. Data = 12.hdr, Mask = 12.png, RGB = 10.png
# 10. Data = 13.hdr, Mask = 13.png, RGB = 11.png
# 11. Data = 14.hdr, Mask = 14.png, RGB = 12.png
# 12. Data = 15.hdr, Mask = 15.png, RGB = 13.png
# 13. Data = 16.hdr, Mask = 16.png, RGB = 14.png
# 14. Data = 17.hdr, Mask = 17.png, RGB = 15.png
# 15. Data = 18.hdr, Mask = 18.png, RGB = 16.png
# 16. Data = 19.hdr, Mask = 19.png, RGB = 17.png
# 17. Data = 20.hdr, Mask = 20.png, RGB = 18.png
# 18. Data = 21.hdr, Mask = 21.png, RGB = 19.png
# 19. Data = 22.hdr, Mask = 22.png, RGB = 20.png
# 20. Data = 23.hdr, Mask = 23.png, RGB = 21.png
# 21. Data = 26.hdr, Mask = 26.png, RGB = 22.png
# 22. Data = 27.hdr, Mask = 27.png, RGB = 23.png
# 23. Data = 29.hdr, Mask = 29.png, RGB = 24.png
# 24. Data = 31.hdr, Mask = 31.png, RGB = 25.png
# 25. Data = 32.hdr, Mask = 32.png, RGB = 26.png
# 26. Data = 36.hdr, Mask = 36.png, RGB = 27.png
# 27. Data = 37.hdr, Mask = 37.png, RGB = 28.png
# 28. Data = 38.hdr, Mask = 38.png, RGB = 29.png
# 29. Data = 39.hdr, Mask = 39.png, RGB = 30.png
# 30. Data = 40.hdr, Mask = 40.png, RGB = 31.png
# 31. Data = 41.hdr, Mask = 41.png, RGB = 32.png
# 32. Data = 42.hdr, Mask = 42.png, RGB = 33.png
# 33. Data = 44.hdr, Mask = 44.png, RGB = 34.png
# 34. Data = 45.hdr, Mask = 45.png, RGB = 35.png
# 35. Data = 46.hdr, Mask = 46.png, RGB = 36.png
# 36. Data = 49.hdr, Mask = 49.png, RGB = 37.png
# 37. Data = 51.hdr, Mask = 51.png, RGB = 38.png
# 38. Data = 52.hdr, Mask = 52.png, RGB = 39.png
# 39. Data = 53.hdr, Mask = 53.png, RGB = 40.png
# 40. Data = 54.hdr, Mask = 54.png, RGB = 41.png
# 41. Data = 55.hdr, Mask = 55.png, RGB = 42.png
# 42. Data = 58.hdr, Mask = 58.png, RGB = 43.png
# 43. Data = 59.hdr, Mask = 59.png, RGB = 44.png
# 44. Data = 60.hdr, Mask = 60.png, RGB = 45.png
# 45. Data = 61.hdr, Mask = 61.png, RGB = 46.png
# 46. Data = 63.hdr, Mask = 63.png, RGB = 47.png
# 47. Data = 65.hdr, Mask = 65.png, RGB = 48.png
# 143. Data = 199.hdr, Mask = 199.png, RGB = 149.png
# 144. Data = 200.hdr, Mask = 200.png, RGB = 150.png
# 145. Data = 201.hdr, Mask = 201.png, RGB = 151.png
# 146. Data = 204.hdr, Mask = 204.png, RGB = 152.png
# 147. Data = 208.hdr, Mask = 208.png, RGB = 153.png
# 148. Data = 209.hdr, Mask = 209.png, RGB = 154.png
# 149. Data = 210.hdr, Mask = 210.png, RGB = 155.png
# 150. Data = 211.hdr, Mask = 211.png, RGB = 156.png
# 151. Data = 213.hdr, Mask = 213.png, RGB = 157.png
# 152. Data = 214.hdr, Mask = 214.png, RGB = 158.png
# 153. Data = 215.hdr, Mask = 215.png, RGB = 159.png
# 154. Data = 216.hdr, Mask = 216.png, RGB = 160.png
# 155. Data = 217.hdr, Mask = 217.png, RGB = 161.png
# 156. Data = 218.hdr, Mask = 218.png, RGB = 162.png
# 157. Data = 219.hdr, Mask = 219.png, RGB = 163.png
# 158. Data = 220.hdr, Mask = 220.png, RGB = 164.png
# 159. Data = 221.hdr, Mask = 221.png, RGB = 165.png
# 160. Data = 222.hdr, Mask = 222.png, RGB = 166.png
# 161. Data = 223.hdr, Mask = 223.png, RGB = 167.png
# 162. Data = 224.hdr, Mask = 224.png, RGB = 168.png
# 163. Data = 225.hdr, Mask = 225.png, RGB = 169.png
# 164. Data = 226.hdr, Mask = 226.png, RGB = 170.png
# 165. Data = 227.hdr, Mask = 227.png, RGB = 171.png
# 166. Data = 228.hdr, Mask = 228.png, RGB = 172.png
# 167. Data = 229.hdr, Mask = 229.png, RGB = 173.png
# 168. Data = 230.hdr, Mask = 230.png, RGB = 174.png
# 169. Data = 231.hdr, Mask = 231.png, RGB = 175.png
# 170. Data = 232.hdr, Mask = 232.png, RGB = 176.png
# 171. Data = 233.hdr, Mask = 233.png, RGB = 177.png
# 172. Data = 234.hdr, Mask = 234.png, RGB = 178.png
# 173. Data = 235.hdr, Mask = 235.png, RGB = 179.png
# 174. Data = 236.hdr, Mask = 236.png, RGB = 180.png
# 175. Data = 237.hdr, Mask = 237.png, RGB = 181.png
# 176. Data = 238.hdr, Mask = 238.png, RGB = 182.png
# 177. Data = 239.hdr, Mask = 239.png, RGB = 183.png
# 178. Data = 240.hdr, Mask = 240.png, RGB = 184.png
# 179. Data = 241.hdr, Mask = 241.png, RGB = 185.png
# 180. Data = 242.hdr, Mask = 242.png, RGB = 186.png
# 181. Data = 243.hdr, Mask = 243.png, RGB = 187.png
# 182. Data = 244.hdr, Mask = 244.png, RGB = 188.png

# %%
for i in range(len(data_processor.msi_imgs)):
    print(f'{i}. Image:{data_processor.msi_data_name[i]} \t size: {data_processor.msi_imgs[i].shape}')
# Out:
# 0. Image:1.hdr 	 size: (270, 510, 16)
# 1. Image:10.hdr 	 size: (270, 510, 16)
# 2. Image:100.hdr 	 size: (270, 510, 16)
# 3. Image:103.hdr 	 size: (270, 510, 16)
# 4. Image:104.hdr 	 size: (270, 510, 16)
# 5. Image:105.hdr 	 size: (270, 510, 16)
# 6. Image:106.hdr 	 size: (270, 510, 16)
# 7. Image:109.hdr 	 size: (270, 510, 16)
# 8. Image:110.hdr 	 size: (270, 510, 16)
# 9. Image:111.hdr 	 size: (270, 510, 16)
# 10. Image:112.hdr 	 size: (270, 510, 16)
# 11. Image:113.hdr 	 size: (270, 510, 16)
# 12. Image:115.hdr 	 size: (270, 510, 16)
# 13. Image:116.hdr 	 size: (270, 510, 16)
# 14. Image:117.hdr 	 size: (270, 510, 16)
# 15. Image:118.hdr 	 size: (270, 510, 16)
# 16. Image:119.hdr 	 size: (270, 510, 16)
# 17. Image:12.hdr 	 size: (270, 510, 16)
# 18. Image:120.hdr 	 size: (270, 510, 16)
# 19. Image:121.hdr 	 size: (270, 510, 16)
# 20. Image:123.hdr 	 size: (270, 510, 16)
# 21. Image:124.hdr 	 size: (270, 510, 16)
# 22. Image:125.hdr 	 size: (270, 510, 16)
# 23. Image:126.hdr 	 size: (270, 510, 16)
# 24. Image:127.hdr 	 size: (270, 510, 16)
# 25. Image:128.hdr 	 size: (270, 510, 16)
# 26. Image:129.hdr 	 size: (270, 510, 16)
# 27. Image:13.hdr 	 size: (270, 510, 16)
# 28. Image:133.hdr 	 size: (270, 510, 16)
# 29. Image:14.hdr 	 size: (270, 510, 16)
# 30. Image:142.hdr 	 size: (270, 510, 16)
# 31. Image:143.hdr 	 size: (270, 510, 16)
# 32. Image:144.hdr 	 size: (270, 510, 16)
# 33. Image:145.hdr 	 size: (270, 510, 16)
# 34. Image:147.hdr 	 size: (270, 510, 16)
# 35. Image:148.hdr 	 size: (270, 510, 16)
# 36. Image:149.hdr 	 size: (270, 510, 16)
# 37. Image:15.hdr 	 size: (270, 510, 16)
# 38. Image:150.hdr 	 size: (270, 510, 16)
# 39. Image:152.hdr 	 size: (270, 510, 16)
# 40. Image:153.hdr 	 size: (270, 510, 16)
# 41. Image:154.hdr 	 size: (270, 510, 16)
# 42. Image:156.hdr 	 size: (270, 510, 16)
# 43. Image:157.hdr 	 size: (270, 510, 16)
# 44. Image:16.hdr 	 size: (270, 510, 16)
# 45. Image:162.hdr 	 size: (270, 510, 16)
# 46. Image:163.hdr 	 size: (270, 510, 16)
# 47. Image:165.hdr 	 size: (270, 510, 16)
# 48. Image:167.hdr 	 size: (270, 510, 16)
# 49. Image:168.hdr 	 size: (270, 510, 16)
# 50. Image:169.hdr 	 size: (270, 510, 16)
# 51. Image:17.hdr 	 size: (270, 510, 16)
# 52. Image:170.hdr 	 size: (270, 510, 16)
# 53. Image:171.hdr 	 size: (270, 510, 16)
# 54. Image:172.hdr 	 size: (270, 510, 16)
# 55. Image:173.hdr 	 size: (270, 510, 16)
# 56. Image:174.hdr 	 size: (270, 510, 16)
# 57. Image:175.hdr 	 size: (270, 510, 16)
# 58. Image:176.hdr 	 size: (270, 510, 16)
# 59. Image:177.hdr 	 size: (270, 510, 16)
# 60. Image:178.hdr 	 size: (270, 510, 16)
# 61. Image:179.hdr 	 size: (270, 510, 16)
# 62. Image:18.hdr 	 size: (270, 510, 16)
# 63. Image:180.hdr 	 size: (270, 510, 16)
# 64. Image:181.hdr 	 size: (270, 510, 16)
# 65. Image:183.hdr 	 size: (270, 510, 16)
# 66. Image:184.hdr 	 size: (270, 510, 16)
# 67. Image:185.hdr 	 size: (270, 510, 16)
# 68. Image:188.hdr 	 size: (270, 510, 16)
# 69. Image:189.hdr 	 size: (270, 510, 16)
# 70. Image:19.hdr 	 size: (270, 510, 16)
# 71. Image:190.hdr 	 size: (270, 510, 16)
# 72. Image:192.hdr 	 size: (270, 510, 16)
# 73. Image:193.hdr 	 size: (270, 510, 16)
# 74. Image:194.hdr 	 size: (270, 510, 16)
# 75. Image:195.hdr 	 size: (270, 510, 16)
# 76. Image:196.hdr 	 size: (270, 510, 16)
# 77. Image:197.hdr 	 size: (270, 510, 16)
# 78. Image:198.hdr 	 size: (270, 510, 16)
# 79. Image:199.hdr 	 size: (270, 510, 16)
# 80. Image:2.hdr 	 size: (270, 510, 16)
# 81. Image:20.hdr 	 size: (270, 510, 16)
# 82. Image:200.hdr 	 size: (270, 510, 16)
# 83. Image:201.hdr 	 size: (270, 510, 16)
# 84. Image:204.hdr 	 size: (270, 510, 16)
# 85. Image:208.hdr 	 size: (270, 510, 16)
# 86. Image:209.hdr 	 size: (270, 510, 16)
# 87. Image:21.hdr 	 size: (270, 510, 16)
# 88. Image:210.hdr 	 size: (270, 510, 16)
# 89. Image:211.hdr 	 size: (270, 510, 16)
# 90. Image:213.hdr 	 size: (270, 510, 16)
# 91. Image:214.hdr 	 size: (270, 510, 16)
# 92. Image:215.hdr 	 size: (270, 510, 16)
# 93. Image:216.hdr 	 size: (270, 510, 16)
# 94. Image:217.hdr 	 size: (270, 510, 16)
# 95. Image:218.hdr 	 size: (270, 510, 16)
# 96. Image:219.hdr 	 size: (270, 510, 16)
# 97. Image:22.hdr 	 size: (270, 510, 16)
# 98. Image:220.hdr 	 size: (270, 510, 16)
# 99. Image:221.hdr 	 size: (270, 510, 16)
# 100. Image:222.hdr 	 size: (270, 510, 16)
# 101. Image:223.hdr 	 size: (270, 510, 16)
# 102. Image:224.hdr 	 size: (270, 510, 16)
# 103. Image:225.hdr 	 size: (270, 510, 16)
# 104. Image:226.hdr 	 size: (270, 510, 16)
# 105. Image:227.hdr 	 size: (270, 510, 16)
# 106. Image:228.hdr 	 size: (270, 510, 16)
# 107. Image:229.hdr 	 size: (270, 510, 16)
# 108. Image:23.hdr 	 size: (270, 510, 16)
# 109. Image:230.hdr 	 size: (270, 510, 16)
# 110. Image:231.hdr 	 size: (270, 510, 16)
# 111. Image:232.hdr 	 size: (270, 510, 16)
# 112. Image:233.hdr 	 size: (270, 510, 16)
# 113. Image:234.hdr 	 size: (270, 510, 16)
# 114. Image:235.hdr 	 size: (270, 510, 16)
# 115. Image:236.hdr 	 size: (270, 510, 16)
# 116. Image:237.hdr 	 size: (270, 510, 16)
# 117. Image:238.hdr 	 size: (270, 510, 16)
# 118. Image:239.hdr 	 size: (270, 510, 16)
# 119. Image:240.hdr 	 size: (270, 510, 16)
# 120. Image:241.hdr 	 size: (270, 510, 16)
# 121. Image:242.hdr 	 size: (270, 510, 16)
# 122. Image:243.hdr 	 size: (270, 510, 16)
# 123. Image:244.hdr 	 size: (270, 510, 16)
# 124. Image:26.hdr 	 size: (270, 510, 16)
# 125. Image:27.hdr 	 size: (270, 510, 16)
# 126. Image:29.hdr 	 size: (270, 510, 16)
# 127. Image:3.hdr 	 size: (270, 510, 16)
# 128. Image:31.hdr 	 size: (270, 510, 16)
# 129. Image:32.hdr 	 size: (270, 510, 16)
# 130. Image:36.hdr 	 size: (270, 510, 16)
# 131. Image:37.hdr 	 size: (270, 510, 16)
# 132. Image:38.hdr 	 size: (270, 510, 16)
# 133. Image:39.hdr 	 size: (270, 510, 16)
# 134. Image:4.hdr 	 size: (270, 510, 16)
# 135. Image:40.hdr 	 size: (270, 510, 16)
# 136. Image:41.hdr 	 size: (270, 510, 16)
# 137. Image:42.hdr 	 size: (270, 510, 16)
# 138. Image:44.hdr 	 size: (270, 510, 16)
# 139. Image:45.hdr 	 size: (270, 510, 16)
# 140. Image:46.hdr 	 size: (270, 510, 16)
# 141. Image:49.hdr 	 size: (270, 510, 16)
# 142. Image:51.hdr 	 size: (270, 510, 16)
# 143. Image:52.hdr 	 size: (270, 510, 16)
# 144. Image:53.hdr 	 size: (270, 510, 16)
# 145. Image:54.hdr 	 size: (270, 510, 16)
# 146. Image:55.hdr 	 size: (270, 510, 16)
# 147. Image:58.hdr 	 size: (270, 510, 16)
# 148. Image:59.hdr 	 size: (270, 510, 16)
# 149. Image:6.hdr 	 size: (270, 510, 16)
# 150. Image:60.hdr 	 size: (270, 510, 16)
# 151. Image:61.hdr 	 size: (270, 510, 16)
# 152. Image:63.hdr 	 size: (270, 510, 16)
# 153. Image:65.hdr 	 size: (270, 510, 16)
# 154. Image:66.hdr 	 size: (270, 510, 16)
# 155. Image:67.hdr 	 size: (270, 510, 16)
# 156. Image:68.hdr 	 size: (270, 510, 16)
# 157. Image:69.hdr 	 size: (270, 510, 16)
# 158. Image:7.hdr 	 size: (270, 510, 16)
# 159. Image:70.hdr 	 size: (270, 510, 16)
# 160. Image:71.hdr 	 size: (270, 510, 16)
# 161. Image:72.hdr 	 size: (270, 510, 16)
# 162. Image:73.hdr 	 size: (270, 510, 16)
# 163. Image:74.hdr 	 size: (270, 510, 16)
# 164. Image:75.hdr 	 size: (270, 510, 16)
# 165. Image:76.hdr 	 size: (270, 510, 16)
# 166. Image:79.hdr 	 size: (270, 510, 16)
# 167. Image:8.hdr 	 size: (270, 510, 16)
# 168. Image:80.hdr 	 size: (270, 510, 16)
# 169. Image:81.hdr 	 size: (270, 510, 16)
# 170. Image:86.hdr 	 size: (270, 510, 16)
# 171. Image:87.hdr 	 size: (270, 510, 16)
# 172. Image:88.hdr 	 size: (270, 510, 16)
# 173. Image:89.hdr 	 size: (270, 510, 16)
# 174. Image:9.hdr 	 size: (270, 510, 16)
# 175. Image:90.hdr 	 size: (270, 510, 16)
# 176. Image:92.hdr 	 size: (270, 510, 16)
# 177. Image:94.hdr 	 size: (270, 510, 16)
# 178. Image:95.hdr 	 size: (270, 510, 16)
# 179. Image:96.hdr 	 size: (270, 510, 16)
# 180. Image:97.hdr 	 size: (270, 510, 16)
# 181. Image:98.hdr 	 size: (270, 510, 16)
# 182. Image:99.hdr 	 size: (270, 510, 16)

# %%
def oxy_cal(img):
   # R542 = 52096 , 49708
   # R572 = 49172, 43340 
    attmat = np.array([[52096,49708],[49172,43340]])

    lnR544 = np.log(img[:,:,10])  #changing reflectance to absorbance
    lnR572 = np.log(img[:,:,14])  #800

    has_inf = np.isinf(lnR544).any()

    if has_inf:
        print("The image contains inf values.")
 
    lnR544 = np.nan_to_num(lnR544)
    lnR572 = np.nan_to_num(lnR572)

    lnR544 = lnR544.reshape(270*510)
    lnR572 = lnR572.reshape(270*510)
    
    y = np.linalg.lstsq(attmat, [lnR544, lnR572])[0]
    hbo2 = y[0]
    hb = y[1]
    hbO2 = hbo2.reshape(270,510)
    Hbb = hb.reshape(270,510)

    n_Hb = ((Hbb- Hbb.min())/(Hbb.max()-Hbb.min())) * 100
    n_HbO2 = ((hbO2- hbO2.min())/(hbO2.max()-hbO2.min())) * 100

    StO2 = n_HbO2/(n_Hb+n_HbO2)
    n_StO2 = ((StO2 - StO2.min()))/(StO2.max() - StO2.min()) * 100        
    return n_Hb, n_HbO2, n_StO2

# %%
def analyser(rgbs, imgs, masks, data_names):
    mean_StO2 = []
    
    for i in range(len(imgs)):
        image = imgs[i]
        mask = masks[i]
        rgb = rgbs[i]

        Hb, HbO2, StO2 = oxy_cal(image)
        masked_data = cv2.bitwise_and(StO2, StO2, mask=mask)
        
        unmasked_pixels = masked_data[np.nonzero(masked_data)]
        mean_StO2.append(np.mean(unmasked_pixels))
    
    return mean_StO2, data_names

# %%
#Calculating the StO2 and generating spectral graph - Leuko
image_mean_StO2, data_names = analyser(data_processor.msi_rgbs, data_processor.msi_imgs, data_processor.msi_masks, data_processor.msi_data_name)
# Out:
# C:\Users\htic\AppData\Local\Temp\ipykernel_25468\4175512468.py:6: RuntimeWarning: invalid value encountered in log
#   lnR544 = np.log(img[:,:,10])  #changing reflectance to absorbance
# C:\Users\htic\AppData\Local\Temp\ipykernel_25468\4175512468.py:7: RuntimeWarning: invalid value encountered in log
#   lnR572 = np.log(img[:,:,14])  #800
# C:\Users\htic\AppData\Local\Temp\ipykernel_25468\4175512468.py:20: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   y = np.linalg.lstsq(attmat, [lnR544, lnR572])[0]

# %%
result_df = pd.DataFrame({'Data Name': data_names, 'StO2': image_mean_StO2})

# Save the DataFrame to an Excel file
writer = pd.ExcelWriter("C:/Users/htic/Documents/Jupyter/MSI_Oral_Analysis/StO2_all_data.xlsx")
result_df.to_excel(writer, sheet_name="StO2", index=False)
writer.save()
